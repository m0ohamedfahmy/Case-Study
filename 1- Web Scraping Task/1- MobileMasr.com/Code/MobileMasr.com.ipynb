# %% [markdown]
# # Web Scraping MobileMasr.com
#
# In this notebook, I demonstrate **two different approaches** to writing Python web scraping code:
#
# 1. **Monolithic Approach (All-in-One Code)**
#    - In this approach, the entire scraping process is written in one continuous block of code.
#    - It includes fetching pages, parsing HTML, extracting product details, and writing to CSV all together.
#    - This method is simple for small scripts but can become hard to maintain and read for larger projects.
#
# 2. **Modular Approach (Using Functions)**
#    - In this approach, the code is divided into **functions** for each specific task, such as:
#      - Creating the CSV file
#      - Fetching a webpage
#      - Parsing a product card
#      - Writing data to CSV
#      - Main loop controlling the scraping
#    - This method improves **readability, reusability, and maintainability**.
#    - Each function has a clear responsibility, making the code easier to debug and extend.
#
# Both methods achieve the same end result: scraping mobile phone data from the website and saving it to a CSV file.
# The difference lies in **code organization and readability**.

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 1- Monolithic Approach (All-in-One Code)

# %%
# Library
import requests
from bs4 import BeautifulSoup
import csv
import re
import pandas as pd

# %%
# Create CSV file and write header
with open('mobile_misr_phones_1.csv','w',encoding='utf-8',newline='') as f:
    writer = csv.writer(f)  # create CSV writer
    writer.writerow(['product_name','price','seller','status','battery_condition','warranty_period',
                     'memory_size','RAM_size','color','page_number','product_url'])  # write column headers

page_number = 1  # start with first page
count = 0  # counter for total products
status_dict = {'جديد':'new','مستعمل':'used'}  # map Arabic status to English

while True:  # loop through pages until no more
    url = f'https://mobilemasr.com/category/%D9%85%D9%88%D8%A8%D8%A7%D9%8A%D9%84/products?page={page_number}'  # construct page URL
    response = requests.get(url)  # fetch page content
    soup = BeautifulSoup(response.text,'html.parser')  # parse HTML content
    print(f'( Starting to scrape page : {page_number} )'.center(80, " "))  # print status
    print("-------------------------------".center(80, " "))

    # open CSV in append mode to write product data
    with open('mobile_misr_phones_1.csv','a',encoding='utf-8',newline='') as f:
        writer = csv.DictWriter(f, fieldnames=['product_name','price','seller','status','battery_condition',
                                               'warranty_period','memory_size','RAM_size','color','page_number','product_url'])
        
        dash_line = "."  # for loading indicator

        # iterate over all product links on the page
        for item in soup.find_all('a', attrs={'class':'h-[55px] p-0 m-0'}):
            print(f"\rLoading {dash_line}", end="")  # show loading dots
            dash_line += "."
            seller, warranty_period, battery_condition = [], [], []  # initialize lists

            # extract main page product info like....battery info and warranty info
            product_card = item.find_parent('div', class_='product-card')  # find parent card
            if product_card:
                for span in product_card.select('span[class*="inline-flex"]'):
                    if re.search(r'[A-Za-z%]', span.get_text()):
                        battery_condition.append(span.get_text())  # battery info
                    else:
                        warranty_period.append(span.get_text())  # warranty info

            # go to product detail page for more info
            link_tag = item.get('href')  # get product link
            full_url = "https://mobilemasr.com" + link_tag  # complete URL
            second_response = requests.get(full_url)  # fetch product page
            second_soup = BeautifulSoup(second_response.text, "html.parser")  # parse HTML
            
            # Extract Moemory Size , RAM Size , Color
            phone_details = [span.get_text(strip=True) for span in second_soup.find_all('span', attrs={'class': 'mx-1'})[:3]]  # memory, RAM, color

            # extract seller name
            if second_soup.find('h3', attrs={'class': 'mx-2 mt-1'}) is None:
                seller.append(second_soup.find('span', attrs={'class': 'mx-1 text-sm'}).get_text())
            else:
                seller.append(second_soup.find('h3', attrs={'class': 'mx-2 mt-1'}).contents[0].strip())

            # write product data to CSV
            writer.writerow({
                'product_name': (re.split(r'\s+(?:رامات|جيجابايت)\s+', second_soup.find('h1').get_text())[0].strip()
                                 if second_soup.find('h1') else 'N/A'), 
                'price': (second_soup.find('h4').get_text().split()[0] if second_soup.find('h4') else 'N/A'),  
                'seller': (seller[0] if seller else None),  # seller
                'status': (status_dict.get(second_soup.select('span[class*="text-xs"]')[0].get_text(strip=True))
                           if second_soup.select('span[class*="text-xs"]') else 'N/A'), 
                'memory_size': phone_details[0].split()[0] if len(phone_details) > 0 else 'N/A',  
                'RAM_size': phone_details[1].split()[0] if len(phone_details) > 1 else 'N/A',  
                'color': phone_details[2].split()[0] if len(phone_details) > 2 else 'N/A',  
                'page_number': page_number,  
                'product_url': full_url, 
                'warranty_period': (warranty_period[0] if warranty_period else 'N/A'),  
                'battery_condition': (battery_condition[0] if battery_condition else 'N/A')  
            })
            count += 1  # increase product counter
            warranty_period = []  # reset for next product
            battery_condition = []  # reset for next product

    # print summary for the page
    print(f"\nSuccessfully scraped page ( {page_number} ) with ( {count} ) products.".center(80, " "))
    count=0
    print('='*80)

    # check if there are more pages
    if len(soup.find_all('span', attrs={'class':'hidden sm:flex'})) != 0:
        page_number += 1  # next page
    else:
        print('Finished All Pages')  # no more pages
        break
# Out:
#                         ( Starting to scrape page : 1 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 1 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 2 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 2 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 3 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 3 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 4 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 4 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 5 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 5 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 6 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 6 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 7 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 7 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 8 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 8 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 9 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 9 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 10 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 10 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 11 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 11 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 12 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 12 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 13 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 13 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 14 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 14 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 15 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 15 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 16 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 16 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 17 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 17 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 18 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 18 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 19 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 19 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 20 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 20 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 21 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 21 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 22 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 22 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 23 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 23 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 24 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 24 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 25 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 25 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 26 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 26 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 27 )
#                         -------------------------------
#
# Successfully scraped page ( 27 ) with ( 0 ) products.
# ================================================================================
# Finished All Pages

# %%
df= pd.read_csv('mobile_misr_phones_1.csv')
df
# Out:
#                         product_name   price      seller status
# 0               أبل أيفون 16 Pro Max  77,000    Harmony1   used  \
# 1                   ايفون 15 Pro Max  55,680    Harmony1   used
# 2                   هونر Magic 6 Pro  37,250    Harmony1   used
# 3               أبل أيفون 16 Pro Max  68,600    Harmony+   used
# 4                   فيفو V50 Lite 5G  15,100    Harmony1    new
# ..                               ...     ...         ...    ...
# 619  شاومي Redmi Note 14 Pro Plus 5G  21,380    Harmony+    new
# 620                    ريلمي Note 50   6,035    Harmony1    new
# 621                 ايفون 16 Pro Max  73,000    FM store    new
# 622                 ايفون 14 Pro Max  47,320    Harmony+   used
# 623                     وان بلس Open  54,780  El Hawakmy   used
#
#     battery_condition   warranty_period  memory_size  RAM_size     color
# 0               100 %       ضمان ٣٠ يوم          512         8  تيتانيوم  \
# 1                87 %       ضمان ٣٠ يوم          256         8  تيتانيوم
# 2           very good       ضمان ٣٠ يوم          512        12      أسود
# 3               100 %       ضمان ٣٠ يوم          256         8  تايتنيوم
# 4                 NaN  ضمان محلي 12 شهر          256        12      ذهبي
# ..                ...               ...          ...       ...       ...
# 619               NaN  ضمان محلي 12 شهر          256        12    بنفسجي
# 620               NaN  ضمان محلي 12 شهر          128         4      أسود
# 621               NaN  ضمان دولي 12 شهر          256         8  تيتانيوم
# 622              85 %       ضمان ٣٠ يوم          256         6      أسود
# 623         very good       ضمان ٣٠ يوم          512        16      أسود
#
#      page_number                                        product_url
# 0              1  https://mobilemasr.com/products/show/%D8%A3%D8...
# 1              1  https://mobilemasr.com/products/show/%D8%A7%D9...
# 2              1  https://mobilemasr.com/products/show/%D9%87%D9...
# 3              1  https://mobilemasr.com/products/show/%D8%A3%D8...
# 4              1  https://mobilemasr.com/products/show/%D9%81%D9...
# ..           ...                                                ...
# 619           26  https://mobilemasr.com/products/show/%D8%B4%D8...
# 620           26  https://mobilemasr.com/products/show/%D8%B1%D9...
# 621           26  https://mobilemasr.com/products/show/%D8%A7%D9...
# 622           26  https://mobilemasr.com/products/show/%D8%A7%D9...
# 623           26  https://mobilemasr.com/products/show/%D9%88%D8...
#
# [624 rows x 11 columns]

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 2- Modular Approach (Using Functions)

# %%
# Variable

csv_file = 'mobile_misr_phones_1.csv'
fieldnames = ['product_name','price','seller','status','battery_condition','warranty_period',
              'memory_size','ram_size','color','page_number','product_url']
status_dict = {'جديد':'new','مستعمل':'used'}

# %%
def create_csv():
    """
    Create a CSV file and write the header row.
    
    This function initializes the CSV file where all scraped
    mobile phone data will be saved.
    """
    with open(csv_file,'w',encoding='utf-8',newline='') as f:
        writer = csv.writer(f)
        writer.writerow(fieldnames)

# %%
def fetch_page(url):
    """
    Fetch a webpage and return a BeautifulSoup object.
    
    Parameters:
        url (str): The URL of the webpage to fetch.
    
    Returns:
        BeautifulSoup object if the page is fetched successfully, otherwise None in case of a request error.
    """
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        return BeautifulSoup(response.text,'html.parser')
    except requests.RequestException as e:
        print(f"[Error] Failed to fetch {url}: {e}")
        return None

# %%
def parse_product_card(item, page_number):
    """
    Extract product details from the main page and the product detail page.
    
    Parameters:
        item : The HTML element containing the product card.
        page_number (int): The current page number being scraped.
    
    Returns:
        dict: A dictionary containing all extracted product information.
        None: If the product detail page could not be fetched.
    """
    seller_list, warranty_list, battery_list = [], [], []

    # Extract basic info from the main page
    product_card = item.find_parent('div', class_='product-card')
    if product_card:
        for span in product_card.select('span[class*="inline-flex"]'):
            if re.search(r'[A-Za-z%]', span.get_text()):
                battery_list.append(span.get_text())
            else:
                warranty_list.append(span.get_text())

    # Extract detailed info from the product's own page
    link_tag = item.get('href')
    full_url = "https://mobilemasr.com" + link_tag
    second_soup = fetch_page(full_url)
    if second_soup is None:
        return None

    # Extract Moemory Size , RAM Size , Color
    phone_details = [span.get_text(strip=True) for span in second_soup.find_all('span', attrs={'class': 'mx-1'})[:3]]

    # Extract seller information
    if second_soup.find('h3', attrs={'class': 'mx-2 mt-1'}) is None:
        seller_list.append(second_soup.find('span', attrs={'class': 'mx-1 text-sm'}).get_text())
    else:
        seller_list.append(second_soup.find('h3', attrs={'class': 'mx-2 mt-1'}).contents[0].strip())

    # Create a dictionary of all product information
    product_data = {
        'product_name': (re.split(r'\s+(?:رامات|جيجابايت)\s+', second_soup.find('h1').get_text())[0].strip()
                         if second_soup.find('h1') else 'N/A'),
        'price': (second_soup.find('h4').get_text().split()[0] if second_soup.find('h4') else 'N/A'),
        'seller': seller_list[0] if seller_list else 'N/A',
        'status': status_dict.get(second_soup.select('span[class*="text-xs"]')[0].get_text(strip=True))
                  if second_soup.select('span[class*="text-xs"]') else 'N/A',
        'memory_size': phone_details[0].split()[0] if len(phone_details) > 0 else 'N/A',
        'ram_size': phone_details[1].split()[0] if len(phone_details) > 1 else 'N/A',
        'color': phone_details[2].split()[0] if len(phone_details) > 2 else 'N/A',
        'page_number': page_number,
        'product_url': full_url,
        'warranty_period': warranty_list[0] if warranty_list else 'N/A',
        'battery_condition': battery_list[0] if battery_list else 'N/A'
    }

    return product_data

# %%
def write_to_csv(data):
    """
    Write a single product's data to the CSV file.
    
    Parameters:
        data (dict): A dictionary containing product information.
    """
    with open(csv_file,'a',encoding='utf-8',newline='') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writerow(data)

# %%
def main():
    """
    Main function to control the scraping process.
    
    - Creates the CSV file
    - Iterates through all product pages
    - Fetches each page and parses all product cards
    - Writes the extracted data to the CSV
    - Handles request errors gracefully
    """
    create_csv()
    page_number = 1
    count = 0

    while True:
        url = f'https://mobilemasr.com/category/%D9%85%D9%88%D8%A8%D8%A7%D9%8A%D9%84/products?page={page_number}'
        soup = fetch_page(url)
        if soup is None:
            print(f"Skipping page {page_number} due to fetch error.")
            page_number += 1
            continue

        print(f'( Starting to scrape page : {page_number} )'.center(80, " "))
        print("-------------------------------".center(80, " "))

        dash_line = "."
        for item in soup.find_all('a', attrs={'class':'h-[55px] p-0 m-0'}):
            print(f"\rLoading {dash_line}", end="")
            dash_line += "."
            product_data = parse_product_card(item, page_number)
            if product_data is not None:
                write_to_csv(product_data)
                count += 1

        print(f"\nSuccessfully scraped page ( {page_number} ) with ( {count} ) products.".center(80, " "))
        print('='*80)
        count=0

        # Check if there are more pages
        if len(soup.find_all('span', attrs={'class':'hidden sm:flex'})) != 0:
            page_number += 1
        else:
            print('Finished All Pages')
            break

# %%
# Run Script 
if __name__ == "__main__":
    main()
# Out:
#                         ( Starting to scrape page : 1 )
#                         -------------------------------
# Loading ....[Error] Failed to fetch https://mobilemasr.com/products/show/%D8%A3%D8%A8%D9%84-%D8%A3%D9%8A%D9%81%D9%88%D9%86-16-pro-max-%D8%B1%D8%A7%D9%85%D8%A7%D8%AA-8-%D8%AC%D9%8A%D8%AC%D8%A7%D8%A8%D8%A7%D9%8A%D8%AA-256-%D8%AC%D9%8A%D8%AC%D8%A7%D8%A8%D8%A7%D9%8A%D8%AA-%D8%AA%D8%A7%D9%8A%D8%AA%D9%86%D9%8A%D9%88%D9%85-%D8%A3%D8%B3%D9%88%D8%AF-(titanium-black)-%D9%85%D9%85%D8%AA%D8%A7%D8%B2-vu016223: HTTPSConnectionPool(host='mobilemasr.com', port=443): Read timed out. (read timeout=10)
# Loading ........................
# Successfully scraped page ( 1 ) with ( 23 ) products.
# ================================================================================
#                         ( Starting to scrape page : 2 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 2 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 3 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 3 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 4 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 4 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 5 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 5 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 6 )
#                         -------------------------------
# Loading .....[Error] Failed to fetch https://mobilemasr.com/products/show/%D9%87%D9%88%D9%86%D8%B1-x5b-%D8%B1%D8%A7%D9%85%D8%A7%D8%AA-4-%D8%AC%D9%8A%D8%AC%D8%A7%D8%A8%D8%A7%D9%8A%D8%AA-64-%D8%AC%D9%8A%D8%AC%D8%A7%D8%A8%D8%A7%D9%8A%D8%AA-%D8%A7%D8%B3%D9%88%D8%AF-%D9%85%D8%B3%D8%AA%D9%8A%D9%83-%D8%AC%D8%AF%D9%8A%D8%AF-vn012828: HTTPSConnectionPool(host='mobilemasr.com', port=443): Read timed out. (read timeout=10)
# Loading ........................
# Successfully scraped page ( 6 ) with ( 23 ) products.
# ================================================================================
#                         ( Starting to scrape page : 7 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 7 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 8 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 8 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 9 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 9 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 10 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 10 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 11 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 11 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 12 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 12 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 13 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 13 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 14 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 14 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 15 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 15 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 16 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 16 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 17 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 17 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 18 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 18 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 19 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 19 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 20 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 20 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 21 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 21 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 22 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 22 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 23 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 23 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 24 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 24 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 25 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 25 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 26 )
#                         -------------------------------
# Loading ........................
# Successfully scraped page ( 26 ) with ( 24 ) products.
# ================================================================================
#                         ( Starting to scrape page : 27 )
#                         -------------------------------
#
# Successfully scraped page ( 27 ) with ( 0 ) products.
# ================================================================================
# Finished All Pages

# %%
import pandas as pd
df= pd.read_csv('mobile_misr_phones_1.csv')
df
# Out:
#                  product_name   price         seller status battery_condition
# 0                    ايفون 13  23,450  Nashwan Store   used              79 %  \
# 1                    هونر 400  23,400       Harmony1    new               NaN
# 2               فيفو Y19s Pro   6,865       El akhwa    new               NaN
# 3          انفنيكس Hot 50i 4G   5,720       El akhwa    new               NaN
# 4            ايفون 16 Pro Max  68,850       Harmony+   used             100 %
# 5    سامسونج جلاكسي S24 Ultra  46,350     El Hawakmy   used         very good
# 6       سامسونج جلاكسي A36 5G  17,180       Harmony+    new               NaN
# 7           شاومي Poco F5 Pro  17,375       Harmony+   used         very good
# 8            أبل أيفون 16 Pro  53,200       Harmony+   used              92 %
# 9                    هونر X9c  15,250       Harmony+   used         very good
# 10       أبل أيفون 16 Pro Max  69,000  Nashwan Store   used              94 %
# 11           ايفون 15 Pro Max  50,000       Harmony+   used              84 %
# 12               ايفون 16 Pro  60,860       Harmony+   used              95 %
# 13           ايفون 15 Pro Max  56,000       Harmony+   used              90 %
# 14              هونر Magic V3  55,320     El Hawakmy   used         very good
# 15                   ايفون 13  25,500       Harmony+   used              76 %
# 16               هونر 200 Pro  26,600       Harmony+   used         very good
# 17           ايفون 15 Pro Max  54,150  Nashwan Store   used              90 %
# 18               ايفون 15 Pro  44,760  Nashwan Store   used              89 %
# 19               ايفون 16 Pro  64,000       Harmony+   used              94 %
# 20      سامسونج جلاكسي A56 5G  18,780       Harmony+    new               NaN
# 21  سامسونج جلاكسي Z Fold6 5G  55,280       Harmony+   used         very good
# 22  سامسونج جلاكسي Z Fold6 5G  53,280       Harmony+   used         very good
# 23                   ايفون 14  29,500       Harmony+   used              85 %
# 24           ايفون 15 Pro Max  54,150  Nashwan Store   used              90 %
# 25               ايفون 16 Pro  64,000       Harmony+   used              94 %
# 26      سامسونج جلاكسي A26 5G  14,145       El akhwa    new               NaN
# 27           أبل أيفون 16 Pro  53,200       Harmony+   used              92 %
# 28               ايفون 14 Pro  39,000  Orange Mobile   used              83 %
# 29      سامسونج جلاكسي A56 5G  18,780       Harmony+    new               NaN
# 30  سامسونج جلاكسي Z Fold6 5G  53,280       Harmony+   used         very good
# 31      سامسونج جلاكسي A56 5G  18,750  Orange Mobile   used         very good
# 32               ايفون 16 Pro  60,860       Harmony+   used              95 %
# 33              هونر Magic V3  55,320     El Hawakmy   used         very good
# 34           ايفون 15 Pro Max  56,000       Harmony+   used              90 %
# 35           ايفون 15 Pro Max  50,000       Harmony+   used              84 %
# 36               هونر 200 Pro  26,600       Harmony+   used         very good
# 37                 اوبو A5 4G   9,880       El akhwa    new               NaN
#
#      warranty_period  memory_size  ram_size     color  page_number
# 0        ضمان ٣٠ يوم          128         4      وردى            1  \
# 1   ضمان محلي 12 شهر          512        12      ذهبي            1
# 2   ضمان محلي 12 شهر          128         6       فضى            1
# 3   ضمان محلي 12 شهر          256         8      اخضر            1
# 4        ضمان ٣٠ يوم          256         8  تيتانيوم            1
# 5        ضمان ٣٠ يوم          512        12  تايتنيوم            1
# 6   ضمان محلي 12 شهر          256         8      أسود            1
# 7        ضمان ٣٠ يوم          256        12      أسود            1
# 8        ضمان ٣٠ يوم          128         8      أبيض            1
# 9        ضمان ٣٠ يوم          256        12  تايتنيوم            1
# 10       ضمان ٣٠ يوم          512         8  تيتانيوم            1
# 11       ضمان ٣٠ يوم          256         8  تايتنيوم            1
# 12       ضمان ٣٠ يوم          256         8  تيتانيوم            1
# 13       ضمان ٣٠ يوم          256         8  تيتانيوم            1
# 14       ضمان ٣٠ يوم          512        12      أسود            1
# 15       ضمان ٣٠ يوم          256         4      أزرق            1
# 16       ضمان ٣٠ يوم          512        12      أزرق            1
# 17       ضمان ٣٠ يوم          256         8  تيتانيوم            1
# 18       ضمان ٣٠ يوم          128         8  تايتنيوم            1
# 19       ضمان ٣٠ يوم          512         8  تيتانيوم            1
# 20  ضمان محلي 12 شهر          128         8    جرافتي            1
# 21       ضمان ٣٠ يوم          256        12       فضي            1
# 22       ضمان ٣٠ يوم          256        12     كُحلي            1
# 23       ضمان ٣٠ يوم          128         6      اصفر            1
# 24       ضمان ٣٠ يوم          256         8  تيتانيوم            2
# 25       ضمان ٣٠ يوم          512         8  تيتانيوم            2
# 26  ضمان محلي 12 شهر          256         8      أسود            2
# 27       ضمان ٣٠ يوم          128         8      أبيض            2
# 28       ضمان ٣٠ يوم          128         6    بنفسجي            2
# 29  ضمان محلي 12 شهر          128         8    جرافتي            2
# 30       ضمان ٣٠ يوم          256        12     كُحلي            2
# 31       ضمان ٣٠ يوم          256         8      وردى            2
# 32       ضمان ٣٠ يوم          256         8  تيتانيوم            2
# 33       ضمان ٣٠ يوم          512        12      أسود            2
# 34       ضمان ٣٠ يوم          256         8  تيتانيوم            2
# 35       ضمان ٣٠ يوم          256         8  تايتنيوم            2
# 36       ضمان ٣٠ يوم          512        12      أزرق            2
# 37  ضمان محلي 12 شهر          256         8      اخضر            2
#
#                                           product_url
# 0   https://mobilemasr.com/products/show/%D8%A7%D9...
# 1   https://mobilemasr.com/products/show/%D9%87%D9...
# 2   https://mobilemasr.com/products/show/%D9%81%D9...
# 3   https://mobilemasr.com/products/show/%D8%A7%D9...
# 4   https://mobilemasr.com/products/show/%D8%A7%D9...
# 5   https://mobilemasr.com/products/show/%D8%B3%D8...
# 6   https://mobilemasr.com/products/show/%D8%B3%D8...
# 7   https://mobilemasr.com/products/show/%D8%B4%D8...
# 8   https://mobilemasr.com/products/show/%D8%A3%D8...
# 9   https://mobilemasr.com/products/show/%D9%87%D9...
# 10  https://mobilemasr.com/products/show/%D8%A3%D8...
# 11  https://mobilemasr.com/products/show/%D8%A7%D9...
# 12  https://mobilemasr.com/products/show/%D8%A7%D9...
# 13  https://mobilemasr.com/products/show/%D8%A7%D9...
# 14  https://mobilemasr.com/products/show/%D9%87%D9...
# 15  https://mobilemasr.com/products/show/%D8%A7%D9...
# 16  https://mobilemasr.com/products/show/%D9%87%D9...
# 17  https://mobilemasr.com/products/show/%D8%A7%D9...
# 18  https://mobilemasr.com/products/show/%D8%A7%D9...
# 19  https://mobilemasr.com/products/show/%D8%A7%D9...
# 20  https://mobilemasr.com/products/show/%D8%B3%D8...
# 21  https://mobilemasr.com/products/show/%D8%B3%D8...
# 22  https://mobilemasr.com/products/show/%D8%B3%D8...
# 23  https://mobilemasr.com/products/show/%D8%A7%D9...
# 24  https://mobilemasr.com/products/show/%D8%A7%D9...
# 25  https://mobilemasr.com/products/show/%D8%A7%D9...
# 26  https://mobilemasr.com/products/show/%D8%B3%D8...
# 27  https://mobilemasr.com/products/show/%D8%A3%D8...
# 28  https://mobilemasr.com/products/show/%D8%A7%D9...
# 29  https://mobilemasr.com/products/show/%D8%B3%D8...
# 30  https://mobilemasr.com/products/show/%D8%B3%D8...
# 31  https://mobilemasr.com/products/show/%D8%B3%D8...
# 32  https://mobilemasr.com/products/show/%D8%A7%D9...
# 33  https://mobilemasr.com/products/show/%D9%87%D9...
# 34  https://mobilemasr.com/products/show/%D8%A7%D9...
# 35  https://mobilemasr.com/products/show/%D8%A7%D9...
# 36  https://mobilemasr.com/products/show/%D9%87%D9...
# 37  https://mobilemasr.com/products/show/%D8%A7%D9...
